# %%
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.base import BaseEstimator, TransformerMixin

from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split

# %%
#%cd ../..
#!ls
# Out:
# /Users/grushinda/Документы /Учеба/МИФИ/Классическое машинное обучение/HomeWorkers/Курсовая работа/IC50_CC50_SI_PROJ_GrushinDA
# EDA           Models        catboost_info

# %%
tmp_data = pd.read_csv('EDA/data/findata-2.csv', index_col=0)

# %%
tmp_data.info(show_counts=True, verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1001 entries, 0 to 1000
# Data columns (total 79 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   IC50, mM             1001 non-null   float64
#  1   CC50, mM             1001 non-null   float64
#  2   SI                   1001 non-null   float64
#  3   MaxAbsEStateIndex    1001 non-null   float64
#  4   MaxEStateIndex       1001 non-null   float64
#  5   MinAbsEStateIndex    1001 non-null   float64
#  6   MinEStateIndex       1001 non-null   float64
#  7   qed                  1001 non-null   float64
#  8   SPS                  1001 non-null   float64
#  9   MolWt                1001 non-null   float64
#  10  HeavyAtomMolWt       1001 non-null   float64
#  11  ExactMolWt           1001 non-null   float64
#  12  NumValenceElectrons  1001 non-null   int64
#  13  MaxPartialCharge     1001 non-null   float64
#  14  MinPartialCharge     1001 non-null   float64
#  15  MaxAbsPartialCharge  1001 non-null   float64
#  16  MinAbsPartialCharge  1001 non-null   float64
#  17  FpDensityMorgan1     1001 non-null   float64
#  18  FpDensityMorgan2     1001 non-null   float64
#  19  FpDensityMorgan3     1001 non-null   float64
#  20  BCUT2D_MWHI          1001 non-null   float64
#  21  BCUT2D_MWLOW         1001 non-null   float64
#  22  BCUT2D_CHGHI         1001 non-null   float64
#  23  BCUT2D_CHGLO         1001 non-null   float64
#  24  BCUT2D_LOGPHI        1001 non-null   float64
#  25  BCUT2D_LOGPLOW       1001 non-null   float64
#  26  BCUT2D_MRHI          1001 non-null   float64
#  27  BCUT2D_MRLOW         1001 non-null   float64
#  28  AvgIpc               1001 non-null   float64
#  29  BalabanJ             1001 non-null   float64
#  30  BertzCT              1001 non-null   float64
#  31  Chi0                 1001 non-null   float64
#  32  Chi0n                1001 non-null   float64
#  33  Chi0v                1001 non-null   float64
#  34  Chi1                 1001 non-null   float64
#  35  Chi1n                1001 non-null   float64
#  36  Chi1v                1001 non-null   float64
#  37  Chi2n                1001 non-null   float64
#  38  Chi2v                1001 non-null   float64
#  39  Chi3n                1001 non-null   float64
#  40  Chi3v                1001 non-null   float64
#  41  Chi4n                1001 non-null   float64
#  42  Chi4v                1001 non-null   float64
#  43  HallKierAlpha        1001 non-null   float64
#  44  Ipc                  1001 non-null   float64
#  45  Kappa1               1001 non-null   float64
#  46  Kappa2               1001 non-null   float64
#  47  Kappa3               1001 non-null   float64
#  48  LabuteASA            1001 non-null   float64
#  49  PEOE_VSA1            1001 non-null   float64
#  50  PEOE_VSA6            1001 non-null   float64
#  51  PEOE_VSA7            1001 non-null   float64
#  52  PEOE_VSA8            1001 non-null   float64
#  53  PEOE_VSA9            1001 non-null   float64
#  54  SMR_VSA1             1001 non-null   float64
#  55  SMR_VSA10            1001 non-null   float64
#  56  SMR_VSA5             1001 non-null   float64
#  57  SlogP_VSA2           1001 non-null   float64
#  58  SlogP_VSA5           1001 non-null   float64
#  59  SlogP_VSA6           1001 non-null   float64
#  60  TPSA                 1001 non-null   float64
#  61  EState_VSA3          1001 non-null   float64
#  62  EState_VSA4          1001 non-null   float64
#  63  EState_VSA8          1001 non-null   float64
#  64  VSA_EState2          1001 non-null   float64
#  65  VSA_EState4          1001 non-null   float64
#  66  VSA_EState5          1001 non-null   float64
#  67  VSA_EState7          1001 non-null   float64
#  68  VSA_EState8          1001 non-null   float64
#  69  FractionCSP3         1001 non-null   float64
#  70  HeavyAtomCount       1001 non-null   int64
#  71  NOCount              1001 non-null   float64
#  72  NumAliphaticRings    1001 non-null   float64
#  73  NumHAcceptors        1001 non-null   float64
#  74  NumHeteroatoms       1001 non-null   float64
#  75  NumRotatableBonds    1001 non-null   float64
#  76  RingCount            1001 non-null   float64
#  77  MolLogP              1001 non-null   float64
#  78  MolMR                1001 non-null   float64
# dtypes: float64(77), int64(2)
# memory usage: 625.6 KB

# %%
go_data = tmp_data.copy()

# %%
# Удалим не нужные тут таргеты 
go_data['bin_target'] = (go_data['SI'] > go_data['SI'].median()).astype(int)

go_data = go_data.drop(columns=['IC50, mM','CC50, mM', 'SI'])

# %%
# Выбираем самые полезные параметры 

# Рассчитываем корреляцию всех признаков 
go_correlations = go_data.corr()['bin_target'].abs().sort_values()

# Отбираем признаки с корреляцией больше 0.1 
gl_high_info_features = go_correlations[go_correlations > 0.1]

print("Информативные признаки (есть связь):")
gl_high_info_features = gl_high_info_features.drop(['bin_target'], errors='ignore')


#Для финальной модели оставляем только информативные параметры  
gl_final_param = gl_high_info_features.index.unique().tolist() 

print(len(gl_final_param))
display(go_correlations.sort_values(ascending=False).head(50))

display(gl_final_param)
# Out:
# Информативные признаки (есть связь):
# 21
# bin_target             1.000000
# FractionCSP3           0.172451
# MaxAbsEStateIndex      0.157832
# MaxEStateIndex         0.157832
# MaxPartialCharge       0.152466
# MinEStateIndex         0.152313
# NumHeteroatoms         0.141485
# MinAbsPartialCharge    0.140818
# VSA_EState8            0.131851
# VSA_EState4            0.131689
# HallKierAlpha          0.126977
# SlogP_VSA6             0.124220
# VSA_EState7            0.123368
# VSA_EState5            0.119751
# BertzCT                0.117032
# BCUT2D_LOGPHI          0.110194
# SMR_VSA1               0.108661
# VSA_EState2            0.107331
# HeavyAtomMolWt         0.103813
# SMR_VSA10              0.101661
# NOCount                0.100570
# SPS                    0.100263
# NumHAcceptors          0.099971
# SlogP_VSA5             0.094632
# SMR_VSA5               0.094132
# BCUT2D_MWLOW           0.093364
# ExactMolWt             0.092314
# MolWt                  0.092267
# MinAbsEStateIndex      0.088383
# Chi1                   0.088145
# RingCount              0.087440
# HeavyAtomCount         0.087104
# Chi0                   0.084667
# AvgIpc                 0.078638
# BCUT2D_MRHI            0.078170
# MaxAbsPartialCharge    0.078056
# NumRotatableBonds      0.077431
# LabuteASA              0.074106
# NumValenceElectrons    0.072935
# PEOE_VSA7              0.072802
# TPSA                   0.071213
# FpDensityMorgan3       0.066457
# NumAliphaticRings      0.064059
# Kappa1                 0.062026
# PEOE_VSA1              0.059695
# BCUT2D_MWHI            0.058016
# Kappa2                 0.050760
# SlogP_VSA2             0.049857
# MolMR                  0.046140
# Chi0v                  0.045456
# Name: bin_target, dtype: float64
# ['SPS',
#  'NOCount',
#  'SMR_VSA10',
#  'HeavyAtomMolWt',
#  'VSA_EState2',
#  'SMR_VSA1',
#  'BCUT2D_LOGPHI',
#  'BertzCT',
#  'VSA_EState5',
#  'VSA_EState7',
#  'SlogP_VSA6',
#  'HallKierAlpha',
#  'VSA_EState4',
#  'VSA_EState8',
#  'MinAbsPartialCharge',
#  'NumHeteroatoms',
#  'MinEStateIndex',
#  'MaxPartialCharge',
#  'MaxEStateIndex',
#  'MaxAbsEStateIndex',
#  'FractionCSP3']

# %%
#перебором выявим параметры котрые коррелируют между собой > 60% и оставим только второй 

for col_1 in gl_final_param:
    for col_2 in gl_final_param:
        if col_1 != col_2:
            lv_correlation = go_data[col_1].corr(go_data[col_2])
            if lv_correlation >= 0.70:
                print(f' Параметр {col_1} коррелирует с парамтером {col_2} : {lv_correlation}')
                gl_final_param.remove(col_2)
display(gl_final_param)
# Out:
#  Параметр SPS коррелирует с парамтером HallKierAlpha : 0.7260631084193933
#  Параметр SPS коррелирует с парамтером FractionCSP3 : 0.8086104934413167
#  Параметр NOCount коррелирует с парамтером HeavyAtomMolWt : 0.7350267381605152
#  Параметр NOCount коррелирует с парамтером BertzCT : 0.7241295784740349
#  Параметр NOCount коррелирует с парамтером NumHeteroatoms : 0.9192452664710238
#  Параметр MinAbsPartialCharge коррелирует с парамтером MaxPartialCharge : 0.9747295044386978
#  Параметр MinAbsPartialCharge коррелирует с парамтером MaxAbsEStateIndex : 0.7537102233342274
#  Параметр MaxEStateIndex коррелирует с парамтером MinAbsPartialCharge : 0.7537102233342274
# ['SPS',
#  'NOCount',
#  'SMR_VSA10',
#  'VSA_EState2',
#  'SMR_VSA1',
#  'BCUT2D_LOGPHI',
#  'VSA_EState5',
#  'VSA_EState7',
#  'SlogP_VSA6',
#  'VSA_EState4',
#  'VSA_EState8',
#  'MinEStateIndex',
#  'MaxEStateIndex']

# %%
go_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1001 entries, 0 to 1000
# Data columns (total 77 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   
#  71  NumHeteroatoms       1001 non-null   float64
#  72  NumRotatableBonds    1001 non-null   float64
#  73  RingCount            1001 non-null   float64
#  74  MolLogP              1001 non-null   float64
#  75  MolMR                1001 non-null   float64
#  76  bin_target           1001 non-null   int64
# dtypes: float64(74), int64(3)
# memory usage: 610.0 KB

# %%
X = go_data[gl_final_param]
#X = go_data.drop(columns='IC50, mM')
y = go_data['bin_target']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

print(f'Train dataset size: {X_train.shape}, {y_train.shape}')
print(f'Test dataset size: {X_test.shape}, {y_test.shape}')
# Out:
# Train dataset size: (700, 13), (700,)
# Test dataset size: (301, 13), (301,)

# %%
print(go_data['bin_target'].value_counts())
# Out:
# bin_target
# 0    501
# 1    500
# Name: count, dtype: int64

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier

models = {
    "LogisticRegression": (LogisticRegression(max_iter=1000), 
        {
            'C': [0.1, 1.0, 10.0], 
            'penalty': ['l2']
        }),

    "RandomForestClassifier": (RandomForestClassifier(), 
        {
            'n_estimators': [50, 150, 350],
            'max_depth': [None, 5, 10]
        }),

    "CatBoostClassifier": (CatBoostClassifier(), 
        {
            'iterations': [50, 150, 350],
            'learning_rate': [0.1, 0.5, 0.7],
            'verbose': [0]

        })
    
}

# %%
from skopt import BayesSearchCV
from sklearn.metrics import silhouette_score
from sklearn.model_selection import PredefinedSplit

# Перебор моделей
best_global_score = -10
best_model = None
results_report = []


for name, (model, params) in models.items():
    print(f"Обучаем {name}...")

    # Байесовская оптимизация гиперпараметров
    bayes_search = BayesSearchCV(
        estimator=model,
        search_spaces=params,
        n_iter=35,
        cv=15,
        scoring='roc_auc',  
        n_jobs=-1,
        random_state=42
    )

    # Обучение модели
    bayes_search.fit(X_train, y_train)

    # 
    score = bayes_search.best_score_  # type: ignore
    results_report.append({"Model": name, "Score": score, "Params": bayes_search.best_params_}) # type: ignore
    
    # Сохраняем абсолютного победителя
    if score > best_global_score:
        best_global_score = score
        best_model = bayes_search.best_estimator_ # type: ignore

# --- АНАЛИЗ ---
print("\n--- Report  ---")
print(pd.DataFrame(results_report))
print(f"\n Лучшая модель: {best_model}")
# Out:
# Обучаем LogisticRegression...
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/multiprocessing/queues.py:120: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   return _ForkingPickler.loads(res)
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/multiprocessing/queues.py:120: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   return _ForkingPickler.loads(res)
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/multiprocessing/queues.py:120: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   return _ForkingPickler.loads(res)
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/multiprocessing/queues.py:120: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   return _ForkingPickler.loads(res)
# Обучаем RandomForestClassifier...
# Обучаем CatBoostClassifier...
#
# --- Report  ---
#                     Model     Score  \
# 0      LogisticRegression  0.599325
# 1  RandomForestClassifier  0.725985
# 2      CatBoostClassifier  0.726494
#
#                                               Params
# 0                       {'C': 10.0, 'penalty': 'l2'}
# 1              {'max_depth': 10, 'n_estimators': 50}
# 2  {'iterations': 50, 'learning_rate': 0.5, 'verb...
#
#  Лучшая модель: CatBoostClassifier(iterations=50, learning_rate=0.5, verbose=0)

# %%
# на тестовой выборке 
from sklearn import metrics

y_pred = best_model.predict(X_test)  # type: ignore

print("MAE", metrics.mean_absolute_error(y_test, y_pred))
print("MSE", metrics.mean_squared_error(y_test, y_pred))
print("R2 Score:", best_model.score(X_test, y_test)) # type: ignore
# Out:
# MAE 0.27906976744186046
# MSE 0.27906976744186046
# R2 Score: 0.7209302325581395
